# %% [markdown]
# # Data Exploration Techniques for Glacier Prove Model

# %% [markdown]
# ### Step 1: Standard Imports

# %%
import pandas as pd
from pathlib import Path
import rasterio
import matplotlib.pyplot as plt
import numpy as np
import os

print('Imported')
# Out:
# Imported

# %%
# Define your base data directories

base_dir = Path("..") # Assumes notebook is in 'notebooks/'
metadata_dir = base_dir / "data/raw/raw_images/metadata"
image_dir = base_dir / "data/raw/raw_images/raw_images"

print(f"Metadata files found: {len(list(metadata_dir.glob('*.txt')))}")
print(f"Image files found: {len(list(image_dir.glob('*.tif')))}")
# Out:
# Metadata files found: 662
# Image files found: 662

# %% [markdown]
# ### Step 2: Building Metadata DataFrame

# %%
def parse_metadata(filepath):
    """Parses a single metadata .txt file into a dictionary."""
    metadata = {}
    with open(filepath, 'r') as f:
        for line in f:
            if ':' in line:
                key, value = line.split(':', 1)
                metadata[key.strip()] = value.strip()
    return metadata

all_metadata = []
print(f"Scanning {metadata_dir}...")

for metadata_file in metadata_dir.glob("*.txt"):
    
    meta = parse_metadata(metadata_file)
    
    # Get the "base name" to find the matching image
    # e.g., "Cook_Front_2018-12-16_S2_RAW"
    base_name = metadata_file.stem.replace("_metadata", "")
    
    # Find the matching image file
    image_file = image_dir / f"{base_name}.tif"
    
    # Add paths and base name to our dictionary
    meta['basename'] = base_name
    meta['metadata_path'] = metadata_file
    meta['image_path'] = image_file
    
    # Check if the matching image actually exists
    if not image_file.exists():
        print(f"Warning: No matching image for {metadata_file.name}")
        meta['image_path'] = None
    
    all_metadata.append(meta)
    
df = pd.DataFrame(all_metadata)
print(f"Successfully parsed {len(df)} metadata files.")
df.head()
# Out:
# Scanning ../data/raw/raw_images/metadata...
# Successfully parsed 662 metadata files.
#              Region  Satellite         Image Type        Date Cloud Cover  \
# 0     Filchner_East  SENTINEL2  RAW (unprocessed)  2020-11-14  22.966096%
# 1     Thwaites_East  SENTINEL2  RAW (unprocessed)  2018-12-21    0.01417%
# 2        Cook_Front  SENTINEL2  RAW (unprocessed)  2018-12-19   0.008758%
# 3     Wilkins_South  SENTINEL2  RAW (unprocessed)  2021-11-08  60.437962%
# 4  Larsen_B_Remnant  SENTINEL2  RAW (unprocessed)  2024-11-07  10.894796%
#
#                                           Product ID  \
# 0  S2B_MSIL2A_20201114T100059_N0214_R093_T24CVU_2...
# 1  S2B_MSIL2A_20181221T152259_N0211_R039_T13CDS_2...
# 2  S2B_MSIL2A_20181219T230339_N0211_R015_T55DFD_2...
# 3  S2B_MSIL2A_20211108T135009_N0301_R081_T18DWH_2...
# 4  S2B_MSIL2A_20241107T125859_N0511_R009_T21DVH_2...
#
#                              Bands                                 Values  \
# 0  B4 (Red), B3 (Green), B2 (Blue)  0-255 (8-bit, converted from 0-10000)
# 1  B4 (Red), B3 (Green), B2 (Blue)  0-255 (8-bit, converted from 0-10000)
# 2  B4 (Red), B3 (Green), B2 (Blue)  0-255 (8-bit, converted from 0-10000)
# 3  B4 (Red), B3 (Green), B2 (Blue)  0-255 (8-bit, converted from 0-10000)
# 4  B4 (Red), B3 (Green), B2 (Blue)  0-255 (8-bit, converted from 0-10000)
#
#                                Processing                            basename  \
# 0  Minimal - divided by 40 for visibility     Filchner_East_2020-11-14_S2_RAW
# 1  Minimal - divided by 40 for visibility     Thwaites_East_2018-12-21_S2_RAW
# 2  Minimal - divided by 40 for visibility        Cook_Front_2018-12-19_S2_RAW
# 3  Minimal - divided by 40 for visibility     Wilkins_South_2021-11-08_S2_RAW
# 4  Minimal - divided by 40 for visibility  Larsen_B_Remnant_2024-11-07_S2_RAW
#
#                                        metadata_path  \
# 0  ../data/raw/raw_images/metadata/Filchner_East_...
# 1  ../data/raw/raw_images/metadata/Thwaites_East_...
# 2  ../data/raw/raw_images/metadata/Cook_Front_201...
# 3  ../data/raw/raw_images/metadata/Wilkins_South_...
# 4  ../data/raw/raw_images/metadata/Larsen_B_Remna...
#
#                                           image_path
# 0  ../data/raw/raw_images/raw_images/Filchner_Eas...
# 1  ../data/raw/raw_images/raw_images/Thwaites_Eas...
# 2  ../data/raw/raw_images/raw_images/Cook_Front_2...
# 3  ../data/raw/raw_images/raw_images/Wilkins_Sout...
# 4  ../data/raw/raw_images/raw_images/Larsen_B_Rem...

# %% [markdown]
# ### Step 3: Answering The Following Questions

# %% [markdown]
# #### 1. How big is the data?

# %%
df.shape
# Out:
# (662, 12)

# %% [markdown]
# #### 2. How does the data look like?

# %%
df.sample(4)
# Out:
#                Region  Satellite         Image Type        Date Cloud Cover  \
# 509        Cook_Front  SENTINEL2  RAW (unprocessed)  2019-11-01   78.00626%
# 350      Ninnis_Front  SENTINEL2  RAW (unprocessed)  2024-11-07   38.99326%
# 36       Totten_Front  SENTINEL2  RAW (unprocessed)  2019-11-27  30.220951%
# 121  Larsen_B_Remnant  SENTINEL2  RAW (unprocessed)  2024-11-03  46.609232%
#
#                                             Product ID  \
# 509  S2B_MSIL2A_20191101T225339_N0213_R115_T55DFD_2...
# 350  S2B_MSIL2A_20241107T230329_N0511_R015_T55DEF_2...
# 36   S2B_MSIL2A_20191127T012539_N0213_R045_T50DMM_2...
# 121  S2B_MSIL2A_20241103T131909_N0511_R095_T20DPN_2...
#
#                                Bands                                 Values  \
# 509  B4 (Red), B3 (Green), B2 (Blue)  0-255 (8-bit, converted from 0-10000)
# 350  B4 (Red), B3 (Green), B2 (Blue)  0-255 (8-bit, converted from 0-10000)
# 36   B4 (Red), B3 (Green), B2 (Blue)  0-255 (8-bit, converted from 0-10000)
# 121  B4 (Red), B3 (Green), B2 (Blue)  0-255 (8-bit, converted from 0-10000)
#
#                                  Processing  \
# 509  Minimal - divided by 40 for visibility
# 350  Minimal - divided by 40 for visibility
# 36   Minimal - divided by 40 for visibility
# 121  Minimal - divided by 40 for visibility
#
#                                basename  \
# 509        Cook_Front_2019-11-01_S2_RAW
# 350      Ninnis_Front_2024-11-07_S2_RAW
# 36       Totten_Front_2019-11-27_S2_RAW
# 121  Larsen_B_Remnant_2024-11-03_S2_RAW
#
#                                          metadata_path  \
# 509  ../data/raw/raw_images/metadata/Cook_Front_201...
# 350  ../data/raw/raw_images/metadata/Ninnis_Front_2...
# 36   ../data/raw/raw_images/metadata/Totten_Front_2...
# 121  ../data/raw/raw_images/metadata/Larsen_B_Remna...
#
#                                             image_path
# 509  ../data/raw/raw_images/raw_images/Cook_Front_2...
# 350  ../data/raw/raw_images/raw_images/Ninnis_Front...
# 36   ../data/raw/raw_images/raw_images/Totten_Front...
# 121  ../data/raw/raw_images/raw_images/Larsen_B_Rem...

# %% [markdown]
# #### 3. What is the data type of cols?

# %%
df.info # seems like encoding is needed after looking at these info
# Out:
# <bound method DataFrame.info of                Region  Satellite         Image Type        Date Cloud Cover  \
# 0       Filchner_East  SENTINEL2  RAW (unprocessed)  2020-11-14  22.966096%
# 1       Thwaites_East  SENTINEL2  RAW (unprocessed)  2018-12-21    0.01417%
# 2          Cook_Front  SENTINEL2  RAW (unprocessed)  2018-12-19   0.008758%
# 3       Wilkins_South  SENTINEL2  RAW (unprocessed)  2021-11-08  60.437962%
# 4    Larsen_B_Remnant  SENTINEL2  RAW (unprocessed)  2024-11-07  10.894796%
# ..                ...        ...                ...         ...         ...
# 657    Larsen_C_North  SENTINEL2  RAW (unprocessed)  2024-11-10  59.147853%
# 658   Ross_North_East  SENTINEL2  RAW (unprocessed)  2024-11-03  39.623296%
# 659  Shackleton_Front  SENTINEL2  RAW (unprocessed)  2024-12-17  53.630602%
# 660  Larsen_C_Central  SENTINEL2  RAW (unprocessed)  2021-11-19  71.174471%
# 661      Totten_Shelf  SENTINEL2  RAW (unprocessed)  2021-11-10    7.50184%
#
#                                             Product ID  \
# 0    S2B_MSIL2A_20201114T100059_N0214_R093_T24CVU_2...
# 1    S2B_MSIL2A_20181221T152259_N0211_R039_T13CDS_2...
# 2    S2B_MSIL2A_20181219T230339_N0211_R015_T55DFD_2...
# 3    S2B_MSIL2A_20211108T135009_N0301_R081_T18DWH_2...
# 4    S2B_MSIL2A_20241107T125859_N0511_R009_T21DVH_2...
# ..                                                 ...
# 657  S2B_MSIL2A_20241110T130859_N0511_R052_T20DNL_2...
# 658  S2B_MSIL2A_20241103T200529_N0511_R099_T59CNP_2...
# 659  S2B_MSIL2A_20241217T025609_N0511_R003_T46DFN_2...
# 660  S2B_MSIL2A_20211119T131909_N0301_R095_T20DNK_2...
# 661  S2B_MSIL2A_20211110T010529_N0301_R102_T50DNM_2...
#
#                                Bands                                 Values  \
# 0    B4 (Red), B3 (Green), B2 (Blue)  0-255 (8-bit, converted from 0-10000)
# 1    B4 (Red), B3 (Green), B2 (Blue)  0-255 (8-bit, converted from 0-10000)
# 2    B4 (Red), B3 (Green), B2 (Blue)  0-255 (8-bit, converted from 0-10000)
# 3    B4 (Red), B3 (Green), B2 (Blue)  0-255 (8-bit, converted from 0-10000)
# 4    B4 (Red), B3 (Green), B2 (Blue)  0-255 (8-bit, converted from 0-10000)
# ..                               ...                                    ...
# 657  B4 (Red), B3 (Green), B2 (Blue)  0-255 (8-bit, converted from 0-10000)
# 658  B4 (Red), B3 (Green), B2 (Blue)  0-255 (8-bit, converted from 0-10000)
# 659  B4 (Red), B3 (Green), B2 (Blue)  0-255 (8-bit, converted from 0-10000)
# 660  B4 (Red), B3 (Green), B2 (Blue)  0-255 (8-bit, converted from 0-10000)
# 661  B4 (Red), B3 (Green), B2 (Blue)  0-255 (8-bit, converted from 0-10000)
#
#                                  Processing  \
# 0    Minimal - divided by 40 for visibility
# 1    Minimal - divided by 40 for visibility
# 2    Minimal - divided by 40 for visibility
# 3    Minimal - divided by 40 for visibility
# 4    Minimal - divided by 40 for visibility
# ..                                      ...
# 657  Minimal - divided by 40 for visibility
# 658  Minimal - divided by 40 for visibility
# 659  Minimal - divided by 40 for visibility
# 660  Minimal - divided by 40 for visibility
# 661  Minimal - divided by 40 for visibility
#
#                                basename  \
# 0       Filchner_East_2020-11-14_S2_RAW
# 1       Thwaites_East_2018-12-21_S2_RAW
# 2          Cook_Front_2018-12-19_S2_RAW
# 3       Wilkins_South_2021-11-08_S2_RAW
# 4    Larsen_B_Remnant_2024-11-07_S2_RAW
# ..                                  ...
# 657    Larsen_C_North_2024-11-10_S2_RAW
# 658   Ross_North_East_2024-11-03_S2_RAW
# 659  Shackleton_Front_2024-12-17_S2_RAW
# 660  Larsen_C_Central_2021-11-19_S2_RAW
# 661      Totten_Shelf_2021-11-10_S2_RAW
#
#                                          metadata_path  \
# 0    ../data/raw/raw_images/metadata/Filchner_East_...
# 1    ../data/raw/raw_images/metadata/Thwaites_East_...
# 2    ../data/raw/raw_images/metadata/Cook_Front_201...
# 3    ../data/raw/raw_images/metadata/Wilkins_South_...
# 4    ../data/raw/raw_images/metadata/Larsen_B_Remna...
# ..                                                 ...
# 657  ../data/raw/raw_images/metadata/Larsen_C_North...
# 658  ../data/raw/raw_images/metadata/Ross_North_Eas...
# 659  ../data/raw/raw_images/metadata/Shackleton_Fro...
# 660  ../data/raw/raw_images/metadata/Larsen_C_Centr...
# 661  ../data/raw/raw_images/metadata/Totten_Shelf_2...
#
#                                             image_path
# 0    ../data/raw/raw_images/raw_images/Filchner_Eas...
# 1    ../data/raw/raw_images/raw_images/Thwaites_Eas...
# 2    ../data/raw/raw_images/raw_images/Cook_Front_2...
# 3    ../data/raw/raw_images/raw_images/Wilkins_Sout...
# 4    ../data/raw/raw_images/raw_images/Larsen_B_Rem...
# ..                                                 ...
# 657  ../data/raw/raw_images/raw_images/Larsen_C_Nor...
# 658  ../data/raw/raw_images/raw_images/Ross_North_E...
# 659  ../data/raw/raw_images/raw_images/Shackleton_F...
# 660  ../data/raw/raw_images/raw_images/Larsen_C_Cen...
# 661  ../data/raw/raw_images/raw_images/Totten_Shelf...
#
# [662 rows x 12 columns]>

# %% [markdown]
# #### 4. Are there any missing values?

# %%
df.isnull().sum() # no missing values present (luckily good)
# Out:
# Region           0
# Satellite        0
# Image Type       0
# Date             0
# Cloud Cover      0
# Product ID       0
# Bands            0
# Values           0
# Processing       0
# basename         0
# metadata_path    0
# image_path       0
# dtype: int64

# %% [markdown]
# #### 5. How does the data look mathematically?

# %%
df.describe()
# Out:
#                   Region  Satellite         Image Type        Date  \
# count                662        662                662         662
# unique                29          1                  1         219
# top     Shackleton_Front  SENTINEL2  RAW (unprocessed)  2024-11-13
# freq                  35        662                662          13
#
#        Cloud Cover                                         Product ID  \
# count          662                                                662
# unique         589                                                589
# top     46.496618%  S2B_MSIL2A_20231109T200539_N0509_R099_T59CNP_2...
# freq             2                                                  2
#
#                                   Bands  \
# count                               662
# unique                                1
# top     B4 (Red), B3 (Green), B2 (Blue)
# freq                                662
#
#                                        Values  \
# count                                     662
# unique                                      1
# top     0-255 (8-bit, converted from 0-10000)
# freq                                      662
#
#                                     Processing  \
# count                                      662
# unique                                       1
# top     Minimal - divided by 40 for visibility
# freq                                       662
#
#                                basename  \
# count                               662
# unique                              662
# top     Filchner_East_2020-11-14_S2_RAW
# freq                                  1
#
#                                             metadata_path  \
# count                                                 662
# unique                                                662
# top     ../data/raw/raw_images/metadata/Filchner_East_...
# freq                                                    1
#
#                                                image_path
# count                                                 662
# unique                                                662
# top     ../data/raw/raw_images/raw_images/Filchner_Eas...
# freq                                                    1

# %% [markdown]
# #### 6. Are there duplicate values?

# %%
df.duplicated().sum() # no
# Out:
# np.int64(0)
